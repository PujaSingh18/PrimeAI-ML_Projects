# %%
# pip install pandas

import pandas as pd

# %%
info = {
    "Name" : ["Rahul", "Prachi", "Pooja"],
    "CGPA" : [9.5, 7.5, 8.5]
}

df = pd.DataFrame(info)
print(df)
# Out:
#      Name  CGPA
# 0   Rahul   9.5
# 1  Prachi   7.5
# 2   Pooja   8.5

# %%
df
# Out:
#      Name  CGPA
# 0   Rahul   9.5
# 1  Prachi   7.5
# 2   Pooja   8.5

# %%
#series
s = pd.Series([1, 2, 3, 4, 5])
print(s)
print(type(s))

#index
print(s[0])
print(s[2])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# 1
# 3

# %%
#label wise
s = pd.Series([24, 21, 30, 32], index=["Raj", "Edan", "Alice", "Roo"])
print(s)
print(s["Alice"])
#print(s[2])  

print(s.index)
# Out:
# Raj      24
# Edan     21
# Alice    30
# Roo      32
# dtype: int64
# 30
# Index(['Raj', 'Edan', 'Alice', 'Roo'], dtype='object')

# %%
#series properties

#homogenouss
s = pd.Series([24, 21, 30, 32, "CEO"], index=["Raj", "Edan", "Alice", "Roo", 65])
print(s)
# Out:
# Raj       24
# Edan      21
# Alice     30
# Roo       32
# 65       CEO
# dtype: object

# %%
#vectorized operation
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([10, 20, 30, 40, 50])

print(s1 + s2)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
#handle missing values with NaN
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([10, 20, 30, 40, 50])

s1[0] = 100
print(s1)

#immutable value
changed_s1 = s1.drop(0)
print(changed_s1)
# Out:
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#Data Frame
info = {
    "Name" : ["Aboo", "Boob", "Ceo", "Deo"],
    "Age" : [10, 20 ,30 ,40],
    "GPA" : [3.00, 9.88, 7.0, 4.0]
}
df = pd.DataFrame(info)
#print(df)
print(df, type(df))
print(df.index)
print(df.columns)
# Out:
#    Name  Age   GPA
# 0  Aboo   10  3.00
# 1  Boob   20  9.88
# 2   Ceo   30  7.00
# 3   Deo   40  4.00 <class 'pandas.core.frame.DataFrame'>
# RangeIndex(start=0, stop=4, step=1)
# Index(['Name', 'Age', 'GPA'], dtype='object')

# %%
df = pd.DataFrame([["Abb", 25], ["Beo", 17], ["Coo", 55]], columns = ["Name", "Age"])
print(df)
# Out:
#   Name  Age
# 0  Abb   25
# 1  Beo   17
# 2  Coo   55

# %%
import numpy as np

np_arr = np.array([[1, 2, 3], [4, 5, 6]])

df = pd.DataFrame(np_arr, columns=["A", "B", "C"])
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
#csv data

df = pd.read_csv(r"C:\Users\Pooja\Installation\Pandas\employee_data.csv")
print(df, type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.core.frame.DataFrame'>

# %%
#json data
df = pd.read_json(r"C:\Users\Pooja\Installation\Pandas\employee_data.json")
print(df, type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.core.frame.DataFrame'>

# %%
#Methods
df.head()  # starting 5 row
df.tail()
df.tail(2)
df.sample()

df.info()

df.shape
df.describe()
df.columns
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     object
#  4   Salary      10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
#AQI Data Set

df = pd.read_csv(r"C:\Users\Pooja\Installation\Pandas\globalAirQuality.csv")
df.head()
df.tail()
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
#selecting data
#columns wise
df["city"]
df["country"]

df[["city", "aqi"]]
df[["country", "temperature"]]

#rows wise

df.loc[0]
df.loc[2]

df.loc[0:2]   #start indx : end indx(inclusive)

df.iloc[2]
df.iloc[0:3]   #start indx : end indx(exclusive)

#cells  - row, col
df.loc[0, "aqi"]
df.loc[0, ["city", "aqi"]]
df.loc[0:2, ["city", "aqi"]]

df.columns

df.iloc[0, 11]   #  11 is aqi index value
df.iloc[0:3, 2]  # 2 is city index value
df.iloc[0:3, 1:5]

# cell
df.at[0, "city"]
df.iat[0, 2]

df["city"]  # view

cities = df["city"].copy()
cities[0] = "Mumbai"  #copy
cities
# Out:
# 0          Mumbai
# 1        New York
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object

# %%
#Filtering of Data

df[df["aqi"] > 100]
df[ (df["aqi"] > 100) & (df["temperature"] > 30)]
df[ (df["aqi"] > 100) & (df["temperature"] < 30)]

#chaining

aqi_data = df[ (df["aqi"] > 100) & (df["temperature"] > 30)][["city", "aqi"]]
aqi_data
aqi_data.iloc[0]
aqi_data.loc[6]


#Query Method    query retuen copy data not view data
aqi_val = 100
df.query("aqi > 100 & temperature > 30")[["city", "aqi"]]
df.query("aqi > @aqi_val & temperature > 30")[["city", "aqi"]]
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 14     New York  121
# 17     New York  127
# 25     New York  113
# ...         ...  ...
# 17947    Zurich  107
# 17950    Zurich  140
# 17975    Zurich  111
# 17976    Zurich  146
# 17991    Zurich  104
#
# [2384 rows x 2 columns]

# %%
# Cleaning Data

# missing value handle

df = pd.read_csv(r"C:\Users\Pooja\Installation\Pandas\raw_data.csv")
df.isnull()
df.isna()

df.isnull().sum()      #missing value
df.dropna()            #not allow any missing value in any row (row drap)
df.dropna(axis=1)       # colum drop

df.fillna(0)               # filling NaN = 0

age_mean = df["age"].mean()

cleaned_data = df.copy()
age_mean = cleaned_data["age"].mean()
cleaned_data["age"] = cleaned_data["age"].fillna(age_mean)


cleaned_data          # copy data updated age colum and original data is same as it's

df.ffill()
df.bfill()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6    Ahmed Khan  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     USA     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  31.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#Handles Duplicate Value

# df.duplicated()
# df["country"].duplicated()
# df[["country", "gender"]].duplicated()

# df.drop_duplicates()
# df2 = df.copy()
# df.drop_duplicates(inplace = True)
# df2

# %%
# Data Types

df.dtypes
df2 = df.copy()

df2 = df2.fillna(0)
df2["age"] = df2["age"].astype("int64").copy()
df2.dtypes

#String Operation

df["gender"].str.lower()
df["gender"].str.upper()

df["name"].str.split(" ")

df["country"].str.contains("india", case=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7       NaN
# 8     False
# 9     False
# 10    False
# Name: country, dtype: object

# %%
aqi_data = pd.read_csv(r"C:\Users\Pooja\Installation\Pandas\globalAirQuality.csv")

aqi_data["timestamp"] = pd.to_datetime(aqi_data["timestamp"])

aqi_data["timestamp"].dtype
# Out:
# dtype('<M8[ns]')

# %%
# date time data
date_str = pd.Series([pd.to_datetime("2026-12-31")])
type(date_str.dtype)
# Out:
# numpy.dtypes.DateTime64DType

# %%
#Transfroming Data
#Feature Enginerring

df2 = df.copy()
# Important Topic
df2["tax"] = df2["income"].apply(lambda x : "20%" if x >= 50000 else "10%")

# Male == M , Female = F , Unknown = U
gehder_map = {"Male" : "M", "Female" : "F", "Unkonwn" : "U"}
df2["gender"] = df2["gender"].map(gehder_map)

df2 = df2.assign(new_income = df2["income"] * 1.1)

df2["country"] = df2["country"].replace("USA", "US")

df2.columns = ["Id", "Name", "Age", "Country", "Gender", "Income", "Tax", "New_Income"]
df2.rename(columns={"Income":"Salary"})
df2.rename(index={1:"First"})

# df2["Income"].sort_values()
df2.sort_values("Income")
# df2.sort_values("Income", ascending=False)
df2=df2.fillna(50)
sorted_df = df2.sort_values(["Income", "Age"])

sorted_df.sort_index()

#reset
sorted_df.reset_index()
sorted_df.reset_index(drop=True)

#Ranking

# sorted_df["Ranking"] = sorted_df["Income"].rank()
# sorted_df["Ranking"] = sorted_df["Income"].rank(ascending=False, method="dense")
# sorted_df["Ranking"] = sorted_df["Income"].rank(ascending=False, method="min")      #minimum value assign
# sorted_df["Ranking"] = sorted_df["Income"].rank(ascending=False, method="max")      #maximum value assign
sorted_df[["Id", "Name", "Age", "Country", "Gender", "Income", "New_Income", "Tax"]]
# Out:
#     Id          Name   Age Country Gender   Income  New_Income  Tax
# 4    4  Maria Garcia  34.0   Spain      F     50.0        50.0  10%
# 9    9   Carlos Ruiz  50.0  Mexico      M  45000.0     49500.0  10%
# 3    3          Alex  50.0      US     50  47000.0     51700.0  10%
# 5    5        Li Wei  27.0   China      M  51000.0     56100.0  20%
# 0    1      John Doe  29.0      US      M  55000.0     60500.0  20%
# 1    1      John Doe  29.0      US      M  55000.0     60500.0  20%
# 10  10   Emily Davis  31.0      US     50  58000.0     63800.0  20%
# 8    8    Rachel Lee  29.0      US      F  62000.0     68200.0  20%
# 2    2    Jane Smith  50.0  Canada      F  62000.0     68200.0  20%
# 7    7    Ahmed Khan  38.0      50      M  68000.0     74800.0  20%
# 6    6            50  45.0   India      F  73000.0     80300.0  20%

# %%
# Shift id column to the end
df2 = df.copy()

new_col_order = [col for col in df2.columns if col != "id"] + ["id"]
print(new_col_order)
df2[new_col_order]
# Out:
# ['name', 'age', 'country', 'gender', 'income', 'id']
#             name   age country   gender   income  id
# 0       John Doe  29.0     USA     Male  55000.0   1
# 1       John Doe  29.0     USA     Male  55000.0   1
# 2     Jane Smith   NaN  Canada   Female  62000.0   2
# 3           Alex   NaN     USA  Unknown  47000.0   3
# 4   Maria Garcia  34.0   Spain   Female      NaN   4
# 5         Li Wei  27.0   China     Male  51000.0   5
# 6            NaN  45.0   India   Female  73000.0   6
# 7     Ahmed Khan  38.0     NaN     Male  68000.0   7
# 8     Rachel Lee  29.0     USA   Female  62000.0   8
# 9    Carlos Ruiz   NaN  Mexico     Male  45000.0   9
# 10   Emily Davis  31.0     USA      NaN  58000.0  10

# %%
#sort the data and store the data in sort_csv
df2 = df.copy()
df2 = df2.drop_duplicates()
df2 = df2.fillna(0)

# sort the data
df2 = df2.sort_values("income")

df2 = df2.reset_index(drop=True)

df2.to_csv(r"C:\Users\Pooja\Installation\Pandas\sorted_data.csv")
df2
# Out:
#    id          name   age country   gender   income
# 0   4  Maria Garcia  34.0   Spain   Female      0.0
# 1   9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 2   3          Alex   0.0     USA  Unknown  47000.0
# 3   5        Li Wei  27.0   China     Male  51000.0
# 4   1      John Doe  29.0     USA     Male  55000.0
# 5  10   Emily Davis  31.0     USA        0  58000.0
# 6   2    Jane Smith   0.0  Canada   Female  62000.0
# 7   8    Rachel Lee  29.0     USA   Female  62000.0
# 8   7    Ahmed Khan  38.0       0     Male  68000.0
# 9   6             0  45.0   India   Female  73000.0

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# Grouping & Aggregation
df.groupby("country")["income"].mean()
df.groupby("country")["income"].min()
df.groupby("country")["income"].max()

df.groupby("gender")["income"].mean()
df.groupby("gender")["income"].max()
df.groupby("gender")["income"].min()

df.groupby("country")["income"].agg(["mean", "min", "max"])
df.groupby("country")["income"].aggregate(["mean", "min", "max"])

#column rename
df.groupby("country")["income"].agg(avg_salary = "mean", min_salary = "min", max_salary ="max")

df.groupby("country").agg({
    "income" : "mean",
    "age" : "mean"
})

df.groupby("country").agg({
    "income" : "max",
    "age" : "mean"
})

df.groupby("country").agg(
    max_salary = ("income" , "max"),
    avg_age = ("age" , "mean")
)
# Out:
#          max_salary  avg_age
# country
# Canada      62000.0      NaN
# China       51000.0     27.0
# India       73000.0     45.0
# Mexico      45000.0      NaN
# Spain           NaN     34.0
# USA         62000.0     29.5

# %%
# Melt & Pivot Data Reshaping

df = pd.DataFrame({
    "country": ["USA", "USA", "India", "India"],
    "year": [2020, 2021, 2020, 2021],
    "sales": [100, 120, 90, 110],
    "profit": [20, 25, 18, 22],
})

melted_df = df.melt(
    id_vars=["country", "year"],  
    value_vars=["sales", "profit"],
    var_name="metrics",         
    value_name="value"
)
melted_df
# Out:
#   country  year metrics  value
# 0     USA  2020   sales    100
# 1     USA  2021   sales    120
# 2   India  2020   sales     90
# 3   India  2021   sales    110
# 4     USA  2020  profit     20
# 5     USA  2021  profit     25
# 6   India  2020  profit     18
# 7   India  2021  profit     22

# %%
df
# Out:
#   country  year  sales  profit
# 0     USA  2020    100      20
# 1     USA  2021    120      25
# 2   India  2020     90      18
# 3   India  2021    110      22

# %%
original = melted_df.pivot(
    index=["country", "year"],
    columns="metrics",
    values="value",
)
original
# Out:
# metrics       profit  sales
# country year
# India   2020      18     90
#         2021      22    110
# USA     2020      20    100
#         2021      25    120

# %%
df = pd.read_csv(r"C:\Users\Pooja\Installation\Pandas\employee_data.csv")
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
#Basic Visualization
#hist() & plot()

# df["Age"].hist()
df.plot(kind="scatter", x="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
# Merging & Jioning Data

df_customers = pd.DataFrame({
    "customer_id" : [1, 2, 3, 4],
    "name" : ["Adam", "Bob", "Charli", "Dave"]
})

df_order = pd.DataFrame({
    "order_id" : [101, 102, 103, 104],
    "customer_id" : [2, 1, 4, 5],
    "amount" : [250, 120, 300, 180]
})

pd.merge(df_customers, df_order, on="customer_id")    #inner join
pd.merge(df_customers, df_order, on="customer_id", how="left")     #left join
pd.merge(df_customers, df_order, on="customer_id", how="right")    #right join
pd.merge(df_customers, df_order, on="customer_id", how="outer")    #outer join
# Out:
#    customer_id    name  order_id  amount
# 0            1    Adam     102.0   120.0
# 1            2     Bob     101.0   250.0
# 2            3  Charli       NaN     NaN
# 3            4    Dave     103.0   300.0
# 4            5     NaN     104.0   180.0

# %%
df_customers
# Out:
#    customer_id    name
# 0            1    Adam
# 1            2     Bob
# 2            3  Charli
# 3            4    Dave

# %%
df_order
# Out:
#    order_id  customer_id  amount
# 0       101            2     250
# 1       102            1     120
# 2       103            4     300
# 3       104            5     180

# %%
# Concatenation
df1 = pd.DataFrame({
    "id" : [1, 2, 3],
    "name" : ["Abde", "Bob", "Charli"]
})

df2 = pd.DataFrame({
    "id" : [4, 5, 6],
    "name" : ["Evil", "Fear", "Goo"]
})
 
pd.concat([df1, df2])    # row
#override the index value
pd.concat([df1, df2], ignore_index=True)

pd.concat([df1, df2], axis=1) #
# Out:
#    id    name  id  name
# 0   1    Abde   4  Evil
# 1   2     Bob   5  Fear
# 2   3  Charli   6   Goo

# %%
df1
# Out:
#    id    name
# 0   1    Abde
# 1   2     Bob
# 2   3  Charli

# %%
df2
# Out:
#    id  name
# 0   4  Evil
# 1   5  Fear
# 2   6   Goo
